# %% [markdown]
# # DIABETIC RETINOPATHY CLASSIFICATION MODEL

# %% [markdown]
# ### DATA COLLECTION AND PREPARATION

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
trainLabels = pd.read_csv('labels.csv')

# %% [markdown]
# # New Section

# %%
path = '/content/drive/My Drive/Colab Notebooks/labels.csv'

trainLabels = pd.read_csv(path)

# %%
# Checking missing values
trainLabels.isnull().any()
# Out:
# id_code      False
# diagnosis    False
# dtype: bool

# %%
trainLabels.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
trainLabels['code'] = ''

# %%
# Rename the diagnosis code
for num in range(len(trainLabels)):
    if trainLabels['diagnosis'][num] == 0:
        trainLabels['code'][num] = 'No DR'
    elif trainLabels['diagnosis'][num] == 1:
        trainLabels['code'][num] = 'Mild DR'
    elif trainLabels['diagnosis'][num] == 2:
        trainLabels['code'][num] = 'Moderate DR'
    elif trainLabels['diagnosis'][num] == 3:
        trainLabels['code'][num] = 'Severe DR'
    else:
        trainLabels['code'][num] = 'Proliferative DR'
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
classes = list(trainLabels['code'].unique())
classes
# Out:
# ['Moderate DR', 'Proliferative DR', 'Mild DR', 'No DR', 'Severe DR']

# %%
# Plot the barchart
import seaborn as sns

# %%
p = sns.countplot(data=trainLabels['diagnosis'], x = trainLabels['diagnosis'])

# %%
# !pip install pivottablejs

# %%
from pivottablejs import pivot_ui
pivot_ui(trainLabels)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### IMAGE PREPROCESSING

# %%
trainStage0Dir = '/content/drive/My Drive/Colab Notebooks/train/stage0'
trainStage1Dir = '/content/drive/My Drive/Colab Notebooks/train/stage1'
trainStage2Dir = '/content/drive/My Drive/Colab Notebooks/train/stage2'
trainStage3Dir = '/content/drive/My Drive/Colab Notebooks/train/stage3'
trainStage4Dir = '/content/drive/My Drive/Colab Notebooks/train/stage4'

# %% [markdown]
# ### IMAGE PREPROCESSING

# %%
import os, shutil

# %%
print('There are {} images with stage0'.format(len(os.listdir(trainStage0Dir))))
print('There are {} images with stage1'.format(len(os.listdir(trainStage1Dir))))
print('There are {} images with stage2'.format(len(os.listdir(trainStage2Dir))))
print('There are {} images with stage3'.format(len(os.listdir(trainStage3Dir))))
print('There are {} images with stage4'.format(len(os.listdir(trainStage4Dir))))
# Out:
# There are 1820 images with stage0
# There are 2052 images with stage1
# There are 2001 images with stage2
# There are 1662 images with stage3
# There are 927 images with stage4

# %%
trainLabels['Height'] = ''
trainLabels['Width'] = ''
trainLabels['Mode'] = ''

# %%
stage0names = [os.path.join(trainStage0Dir, fname) for fname in os.listdir(trainStage0Dir)]
stage1names = [os.path.join(trainStage1Dir, fname) for fname in os.listdir(trainStage1Dir)]
stage2names = [os.path.join(trainStage2Dir, fname) for fname in os.listdir(trainStage2Dir)]
stage3names = [os.path.join(trainStage3Dir, fname) for fname in os.listdir(trainStage3Dir)]
stage4names = [os.path.join(trainStage4Dir, fname) for fname in os.listdir(trainStage4Dir)]

# %%
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
for i in range(len(stage0names)):
  img = image.load_img(stage0names[i])
  for j in range(len(trainLabels)):
    if trainLabels['id_code'][j] == stage0names[i][:-4][53:]:
      trainLabels['Height'][j] = img.height
      trainLabels['Width'][j] = img.width
      trainLabels['Mode'][j] = img.mode
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
for i in range(len(stage1names)):
  img = image.load_img(stage1names[i])
  for j in range(len(trainLabels)):
    if trainLabels['id_code'][j] == stage1names[i][:-4][53:]:
      trainLabels['Height'][j] = img.height
      trainLabels['Width'][j] = img.width
      trainLabels['Mode'][j] = img.mode
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
for i in range(len(stage2names)):
  img = image.load_img(stage2names[i])
  for j in range(len(trainLabels)):
    if trainLabels['id_code'][j] == stage2names[i][:-4][53:]:
      trainLabels['Height'][j] = img.height
      trainLabels['Width'][j] = img.width
      trainLabels['Mode'][j] = img.mode
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
for i in range(len(stage3names)):
  img = image.load_img(stage3names[i])
  for j in range(len(trainLabels)):
    if trainLabels['id_code'][j] == stage3names[i][:-4][53:]:
      trainLabels['Height'][j] = img.height
      trainLabels['Width'][j] = img.width
      trainLabels['Mode'][j] = img.mode
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
for i in range(len(stage4names)):
  img = image.load_img(stage4names[i])
  for j in range(len(trainLabels)):
    if trainLabels['id_code'][j] == stage4names[i][:-4][53:]:
      trainLabels['Height'][j] = img.height
      trainLabels['Width'][j] = img.width
      trainLabels['Mode'][j] = img.mode
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
trainLabels
# Out:
#            id_code  diagnosis              code Height Width Mode
# 0     000c1434d8d7          2       Moderate DR   2136  3216  RGB
# 1     001639a390f0          4  Proliferative DR   2136  3216  RGB
# 2     0024cdab0c1e          1           Mild DR   1736  2416  RGB
# 3     002c21358ce6          0             No DR   1050  1050  RGB
# 4     005b95c28852          0             No DR   1536  2048  RGB
# ...            ...        ...               ...    ...   ...  ...
# 3657  ffa47f6a7bf4          2       Moderate DR   2588  3388  RGB
# 3658  ffc04fed30e6          0             No DR   1536  2048  RGB
# 3659  ffcf7b45f213          2       Moderate DR   2136  3216  RGB
# 3660  ffd97f8cd5aa          0             No DR   1050  1050  RGB
# 3661  ffec9a18a3ce          2       Moderate DR   1958  2588  RGB
#
# [3662 rows x 6 columns]

# %%
# Save the dataframe to a new file
trainLabels.to_csv('/content/drive/My Drive/Colab Notebooks/wrangled_trainLabels.csv')

# %%
# Load the wrangled trainLabels back
trainLabels = pd.read_csv('/content/drive/My Drive/Colab Notebooks/wrangled_trainLabels.csv')

# %%
trainLabels.head()
# Out:
#    Unnamed: 0       id_code  diagnosis              code  Height   Width Mode
# 0           0  000c1434d8d7          2       Moderate DR  2136.0  3216.0  RGB
# 1           1  001639a390f0          4  Proliferative DR  2136.0  3216.0  RGB
# 2           2  0024cdab0c1e          1           Mild DR  1736.0  2416.0  RGB
# 3           3  002c21358ce6          0             No DR  1050.0  1050.0  RGB
# 4           4  005b95c28852          0             No DR  1536.0  2048.0  RGB

# %%
type(trainLabels['Height'][0])
# Out:
# int

# %%
# Find the average height and width to reshape the images
Wsum = 0
Hsum = 0
for i in range(len(trainLabels)):
  if type(trainLabels['Height'][i]) == int and type(trainLabels['Width'][i]) == int:
    Hsum = Hsum + trainLabels['Height'][i]
    Wsum = Wsum + trainLabels['Width'][i]

height_mean = np.round(Hsum / len(trainLabels))
width_mean = np.round(Wsum / len(trainLabels))

# %%
height_mean
# Out:
# 1521.0

# %%
# !pip install opencv-python

# %%
! Perform Image blurring using openCV to remove noise
import cv2

for i in range(len(stage0names)):
  img = image.load_img(stage0names[i])
  blur = cv2.GaussianBlur(img,(5,5),0)
for i in range(len(stage1names)):
  img = image.load_img(stage1names[i])
  blur = cv2.GaussianBlur(img,(5,5),0)
for i in range(len(stage2names)):
  img = image.load_img(stage2names[i])
  blur = cv2.GaussianBlur(img,(5,5),0)
for i in range(len(stage3names)):
  img = image.load_img(stage3names[i])
  blur = cv2.GaussianBlur(img,(5,5),0)
for i in range(len(stage4names)):
  img = image.load_img(stage4names[i])
  blur = cv2.GaussianBlur(img,(5,5),0)
# Out:
# /bin/bash: Perform: command not found

# %% [markdown]
# #### Using ImageDataGenerator to read images from directories

# %% [markdown]
# #### Run Image Augmentation because of the class imbalance

# %%
from keras.preprocessing.image import ImageDataGenerator as IDG
from keras.preprocessing import image

# %%
datagen = IDG(rotation_range=40, width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15, zoom_range=0.1,
            channel_shift_range=10, horizontal_flip=True)

# %%
for i in range(len(stage1names)):
  img = image.load_img(stage1names[i], target_size= (int(height_mean),int(width_mean)))
  x = image.img_to_array(img)
  x = x.reshape((1,) + x.shape)
  j = 0
  for batch in datagen.flow(x, batch_size=1, save_to_dir=trainStage1Dir, save_prefix='A'):
      j += 1
      print('There are {} images with stage1'.format(len(os.listdir(trainStage1Dir))))
      if j % 6 == 0:
          break
# Out:
# There are 371 images with stage1
# There are 372 images with stage1
# There are 373 images with stage1
# There are 374 images with stage1
# There are 375 images with stage1
# There are 376 images with stage1
# There are 377 images with stage1
# There are 378 images with stage1
# There are 379 images with stage1
# There are 380 images with stage1
# There are 381 images with stage1
# There are 382 images with stage1
# There are 383 images with stage1
# There are 384 images with stage1
# There are 385 images with stage1
# There are 386 images with stage1
# There are 387 images with stage1
# There are 388 images with stage1
# There are 389 images with stage1
# There are 390 images with stage1
# There are 391 images with stage1
# There are 392 images with stage1
# There are 393 images with stage1
# There are 394 images with stage1
# There are 395 images with stage1
# There are 396 images with stage1
# There are 397 images with stage1
# There are 398 images with stage1
# ...

# %%
for i in range(len(stage2names)):
  img = image.load_img(stage2names[i], target_size= (int(height_mean),int(width_mean)))
  x = image.img_to_array(img)
  x = x.reshape((1,) + x.shape)
  j = 0
  print('start round: {}'.format(i))
  for batch in datagen.flow(x, batch_size=1, save_to_dir=trainStage2Dir, save_prefix='A'):
      j += 1
      print('There are {} images with stage2'.format(len(os.listdir(trainStage2Dir))))
      if j % 2 == 0:
          break
# Out:
# start round: 0
# There are 1000 images with stage2
# There are 1001 images with stage2
# start round: 1
# There are 1002 images with stage2
# There are 1003 images with stage2
# start round: 2
# There are 1004 images with stage2
# There are 1005 images with stage2
# start round: 3
# There are 1006 images with stage2
# There are 1007 images with stage2
# start round: 4
# There are 1008 images with stage2
# There are 1009 images with stage2
# start round: 5
# There are 1010 images with stage2
# There are 1011 images with stage2
# start round: 6
# There are 1012 images with stage2
# There are 1013 images with stage2
# start round: 7
# There are 1014 images with stage2
# There are 1015 images with stage2
# start round: 8
# There are 1016 images with stage2
# There are 1017 images with stage2
# start round: 9
# There are 1018 images with stage2
# There are 1019 images with stage2
# start round: 10
# There are 1020 images with stage2
# There are 1021 images with stage2
# start round: 11
# ...

# %%
for i in range(len(stage3names)):
  img = image.load_img(stage3names[i], target_size= (int(height_mean),int(width_mean)))
  x = image.img_to_array(img)
  x = x.reshape((1,) + x.shape)
  print('start round: {}'.format(i))
  j = 0
  for batch in datagen.flow(x, batch_size=1, save_to_dir=trainStage3Dir, save_prefix='A'):
      j += 1
      print('There are {} images with stage4'.format(len(os.listdir(trainStage4Dir))))
      if j % 8 == 0:
          break
# Out:
# start round: 0
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# start round: 1
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# start round: 2
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# There are 302 images with stage4
# start round: 3
# There are 302 images with stage4
# There are 302 images with stage4
# ...

# %%
for i in range(len(stage4names)):
  img = image.load_img(stage4names[i], target_size= (int(height_mean),int(width_mean)))
  x = image.img_to_array(img)
  x = x.reshape((1,) + x.shape)
  print('start round: {}'.format(i))
  j = 0
  for batch in datagen.flow(x, batch_size=1, save_to_dir=trainStage4Dir, save_prefix='A'):
      j += 1
      print('There are {} images with stage4'.format(len(os.listdir(trainStage4Dir))))
      if j % 6 == 0:
          break
# Out:
# start round: 0
# There are 345 images with stage4
# There are 346 images with stage4
# There are 347 images with stage4
# There are 306 images with stage4
# There are 307 images with stage4
# There are 308 images with stage4
# start round: 1
# There are 309 images with stage4
# There are 310 images with stage4
# There are 311 images with stage4
# There are 312 images with stage4
# There are 313 images with stage4
# There are 314 images with stage4
# start round: 2
# There are 315 images with stage4
# There are 316 images with stage4
# There are 317 images with stage4
# There are 318 images with stage4
# There are 319 images with stage4
# There are 320 images with stage4
# start round: 3
# There are 321 images with stage4
# There are 322 images with stage4
# There are 323 images with stage4
# There are 324 images with stage4
# There are 325 images with stage4
# There are 326 images with stage4
# start round: 4
# There are 327 images with stage4
# There are 328 images with stage4
# ...

# %%
import matplotlib.pyplot as plt

img = image.load_img(stage2names[i], target_size= (int(height_mean),int(width_mean)))
x = image.img_to_array(img)
x = x.reshape((1,) + x.shape)
j = 0
for batch in datagen.flow(x, batch_size=1, save_to_dir=trainStage2Dir, save_prefix='A'):
    plt.figure(j)
    imgplot = plt.imshow(image.array_to_img(batch[0]))
    j += 1
    
    if j % 4 == 0:
        break
plt.show()

# %%
print('There are {} images with stage4'.format(len(os.listdir(trainStage3Dir))))
# Out:
# There are 1662 images with stage4

# %%
# Rescale all images by 1/255
train_datagen = IDG(rescale=1./255)
#test_datagen = IDG(rescale=1./255)
validation_datagen = IDG(rescale=1./255)

# %%
trainDir = '/content/drive/My Drive/Colab Notebooks/train'
validationDir = '/content/drive/My Drive/Colab Notebooks/validation'

# %%
train_generator = train_datagen.flow_from_directory(
                trainDir, # Target Directory
                batch_size=20,
                class_mode='categorical') # Because we need multi-category labels
validation_generator = validation_datagen.flow_from_directory(
                validationDir, # Target Directory
                batch_size=20,
                class_mode='categorical') # Because we need binary labels
# Out:
# Found 8462 images belonging to 5 classes.
# Found 355 images belonging to 5 classes.

# %%
for data_batch, label_batch in train_generator:
    print(data_batch.shape)
    print(label_batch.shape)
    break
# Out:
# (20, 256, 256, 3)
# (20, 5)

# %%
import matplotlib.pyplot as plt

# %%
# Plot the images with the labels
def plots(img, figsize=(12,6), rows=1, interp = False, titles= None):
    if type(img[0]) is np.ndarray:
        img = np.array(img).astype(np.uint8)
        if(img.shape[-1] != 3):
            img = img.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(img) // rows if len(img) % 2 == 0 else len(img) // rows + 1
    for i in range(len(img)):
        sp = f.add_subplot(rows, cols, i + 1)
        sp.axis('off')
        if titles is not None:
            sp.set_title(titles[i], fontsize = 16)
        plt.imshow(img[i], interpolation=None if interp else 'none')

# %%
img, labels = next(train_generator)
plots(img, titles=labels)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ### Training the Convnet from scratch

# %%
from keras import layers, models
from keras import optimizers

# %% [markdown]
# #### Instantiating the convnet and adding classifier

# %%
retModel1 = models.Sequential()
retModel1.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(256, 256, 3)))
retModel1.add(layers.MaxPooling2D((2,2)))
retModel1.add(layers.Conv2D(64, (3,3), activation='relu'))
retModel1.add(layers.GaussianNoise(stddev = 1))
retModel1.add(layers.GaussianDropout(0.5))
retModel1.add(layers.MaxPooling2D((2,2)))
retModel1.add(layers.Conv2D(128, (3,3), activation='relu'))
retModel1.add(layers.GaussianNoise(stddev = 1))
retModel1.add(layers.GaussianDropout(0.5))
retModel1.add(layers.MaxPooling2D((2,2)))
retModel1.add(layers.Conv2D(128, (3,3), activation='relu'))
retModel1.add(layers.MaxPooling2D((2,2)))
retModel1.add(layers.Flatten())
retModel1.add(layers.GaussianNoise(stddev = 1))
retModel1.add(layers.GaussianDropout(0.5))
retModel1.add(layers.Dense(256, activation='relu'))
retModel1.add(layers.Dense(5, activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %%
retModel1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 254, 254, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 125, 64)      18496
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 125, 125, 64)      0
# _________________________________________________________________
# gaussian_dropout_1 (Gaussian (None, 125, 125, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 60, 128)       73856
# ...

# %% [markdown]
# #### Compiling the Model

# %%
retModel1.compile(loss='categorical_crossentropy',
             optimizer=optimizers.RMSprop(lr=1e-4),
             metrics=['acc'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
import keras
callbacksList = [
    keras.callbacks.EarlyStopping(
    monitor='acc',
    patience=5,
    ),
    keras.callbacks.ModelCheckpoint(
    filepath='/content/drive/My Drive/Colab Notebooks/RetModel.h5',
    monitor='val_loss',
    save_best_only=True,
    )
]

# %% [markdown]
# #### Fitting the Model

# %%
history = retModel1.fit_generator(
        train_generator,
        steps_per_epoch=100,
        callbacks=callbacksList,
        epochs=30,
        validation_data=validation_generator,
        validation_steps=50)

# %% [markdown]
# #### Ploting the Validation and Train Accuracy and Loss

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label = 'Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Using Transfered Learning ResNet

# %%
from keras.applications import ResNet50

# %%
conv_base = ResNet50(weights = 'imagenet',
                 include_top = False,
                 input_shape = (256, 256, 3))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# ...
# 94658560/94653016 [==============================] - 2s 0us/step

# %%
retModel2 = models.Sequential()
retModel2.add(conv_base)
retModel2.add(layers.Flatten())
retModel2.add(layers.Dropout(0.5))
retModel2.add(layers.Dense(256, activation='relu'))
retModel2.add(layers.Dense(5, activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
retModel2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# resnet50 (Model)             (None, 8, 8, 2048)        23587712
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 131072)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 131072)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               33554688
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 1285
# ...
# Total params: 57,143,685
# Trainable params: 57,090,565
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
print('This is the number of trainable weights before freezing the conv base: ', len(retModel2.trainable_weights))
# Out:
# This is the number of trainable weights before freezing the conv base:  216

# %%
conv_base.trainable = False
print('This is the number of trainable weights after freezing the conv base: ', len(retModel2.trainable_weights))
# Out:
# This is the number of trainable weights after freezing the conv base:  4

# %% [markdown]
# #### Compile the Model

# %%
retModel2.compile(loss='categorical_crossentropy',
             optimizer=optimizers.RMSprop(lr=1e-4),
             metrics=['acc'])

# %% [markdown]
# #### Fitting the Model

# %%
callbacksList = [
    keras.callbacks.EarlyStopping(
    monitor='acc',
    patience=5,
    ),
    keras.callbacks.ModelCheckpoint(
    filepath='/content/drive/My Drive/Colab Notebooks/PretrainedRetModel.h5',
    monitor='val_loss',
    save_best_only=True,
    )
]

# %%
history = retModel2.fit_generator(
        train_generator,
        steps_per_epoch=100,
        callbacks=callbacksList,
        epochs=30,
        validation_data=validation_generator,
        validation_steps=50)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 868s 9s/step - loss: 1.1369 - acc: 0.7085 - val_loss: 1.5460 - val_acc: 0.5131
# Epoch 2/30
# 100/100 [==============================] - 823s 8s/step - loss: 0.8916 - acc: 0.7385 - val_loss: 1.6601 - val_acc: 0.4975
# Epoch 3/30
#  99/100 [============================>.] - ETA: 7s - loss: 0.9109 - acc: 0.7409
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in load(self)
#     234                             try:
# --> 235                                 s = read(self.decodermaxblock)
#     236                             except (IndexError, struct.error):
#
# /usr/local/lib/python3.6/dist-packages/PIL/PngImagePlugin.py in load_read(self, read_bytes)
#     658
# --> 659             cid, pos, length = self.png.read()
#     660
#
# ...

# %% [markdown]
# #### Ploting the Validation and Train Accuracy and Loss

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label = 'Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Making Prediction with the Model

# %%
# Import the libraries
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# %%
# Predict probabilities for test set
testDir = '/content/drive/My Drive/Colab Notebooks/test'
test_datagen = IMG(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
                testDir, # Target Directory
                batch_size=20,
                class_mode='categorical')
yhat_probs = retModel2.predict(test_generator, verbose=0)

# Pridict classes
yhat_classes = retModel2.predict_classes(test_generator, verbose=0)

# %%
# Reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %%
# Accuracy: (tp + tn) / (total Positive + total Negative)
accuracy = accuracy_score(test_y, yhat_classes)
print('Accuracy: {}%'.format(accuracy))

# Precision : tp / (tp + fp)
precision = precision_score(test_y, yhat_classes)
print('Precision: {}%'.format(precision))

# Recall: tp / (tp + fn)
recall = recall_score(test_y, yhat_classes)
print('Recall: {}%'.format(recall))

# F1 score: 2 tp / (2 tp + fp + fn)
f1 = f1_score(test_y, yhat_classes)
print('F1 score: {}%'.format(f1))

# %%
# ROC AUC Plot:
auc = roc_auc_score(test_y, yhat_probs)
print('ROC_AUC: {}%'.format(auc))

# Confusion matrix
matrix = confusion_matrix(test_y, yhat_classes)
print(matrix)
